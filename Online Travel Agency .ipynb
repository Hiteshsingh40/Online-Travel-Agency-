# %% [markdown]
# The dataset is from an online travel agency that tracks their users’ browsing history from search to bookings and payments.

# %% [markdown]
# ### Question 1

# %% [raw]
# a.	Load the dataset into Python and identify the type of the dataset features and report them.
# b.	Perform summary statistics and explain what issues these statistics reveal.
# c.	Perform exploratory analysis to identify any collinearities and explain which issues collinearity causes.
# d.	Identify the issues that are encountered in the dataset.
# e.	Propose and implement the solutions for the issues you have found. The issues listed here are not exhaustive. If you encounter any other issues, please propose and implement solutions for those as well.
# f.	Are there any data privacy and security issues in this dataset? If so, what are they? How would you solve these problems?

# %% [markdown]
# ### a. Load the dataset into Python and identify the type of the dataset features and report them.

# %%
#Basic Libraries
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

#Data Visualization Libraries
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Loading the dataset
df = pd.read_csv('train_small.csv',parse_dates=['timestamp'])
df.head()
# Out:
#    search_id           timestamp  site_id  user_country_id  user_hist_stars  \
# 0          4 2012-12-31 08:59:22        5              219              NaN
# 1          4 2012-12-31 08:59:22        5              219              NaN
# 2          4 2012-12-31 08:59:22        5              219              NaN
# 3          4 2012-12-31 08:59:22        5              219              NaN
# 4          4 2012-12-31 08:59:22        5              219              NaN
#
#    user_hist_paid  listing_country_id  listing_id  listing_stars  \
# 0             NaN                 219        3625              4
# 1             NaN                 219       11622              4
# 2             NaN                 219       11826              5
# 3             NaN                 219       22824              3
# 4             NaN                 219       37581              5
#
#    listing_review_score  ...  competitor6_price_percent_diff  \
# 0                   4.0  ...                             NaN
# 1                   4.0  ...                             NaN
# 2                   4.5  ...                             NaN
# 3                   4.0  ...                             NaN
# 4                   4.5  ...                             NaN
#
#    competitor7_rate  competitor7_has_availability  \
# 0               NaN                           NaN
# 1               NaN                           NaN
# 2               NaN                           NaN
# 3               NaN                           NaN
# 4               NaN                           NaN
#
#    competitor7_price_percent_diff  competitor8_rate  \
# 0                             NaN               NaN
# 1                             NaN               NaN
# 2                             NaN               NaN
# 3                             NaN               NaN
# 4                             NaN               NaN
#
#    competitor8_has_availability  competitor8_price_percent_diff  clicked  \
# 0                           NaN                             NaN        0
# 1                           NaN                             NaN        0
# 2                           NaN                             NaN        0
# 3                           NaN                             NaN        0
# 4                           NaN                             NaN        0
#
#    booking_value  booked
# 0            NaN       0
# 1            NaN       0
# 2            NaN       0
# 3            NaN       0
# 4            NaN       0
#
# [5 rows x 54 columns]

# %%
df.tail()
# Out:
#          search_id           timestamp  site_id  user_country_id  \
# 2380552     665573 2013-03-30 16:39:40        5              219
# 2380553     665573 2013-03-30 16:39:40        5              219
# 2380554     665573 2013-03-30 16:39:40        5              219
# 2380555     665573 2013-03-30 16:39:40        5              219
# 2380556     665573 2013-03-30 16:39:40        5              219
#
#          user_hist_stars  user_hist_paid  listing_country_id  listing_id  \
# 2380552              NaN             NaN                 219      117267
# 2380553              NaN             NaN                 219      125075
# 2380554              NaN             NaN                 219      127402
# 2380555              NaN             NaN                 219      128251
# 2380556              NaN             NaN                 219      135414
#
#          listing_stars  listing_review_score  ...  \
# 2380552              4                   4.5  ...
# 2380553              4                   4.5  ...
# 2380554              5                   4.5  ...
# 2380555              3                   4.0  ...
# 2380556              3                   4.0  ...
#
#          competitor6_price_percent_diff  competitor7_rate  \
# 2380552                             NaN               NaN
# 2380553                             NaN               NaN
# 2380554                             NaN               NaN
# 2380555                             NaN               NaN
# 2380556                             NaN               NaN
#
#          competitor7_has_availability  competitor7_price_percent_diff  \
# 2380552                           NaN                             NaN
# 2380553                           NaN                             NaN
# 2380554                           NaN                             NaN
# 2380555                           NaN                             NaN
# 2380556                           NaN                             NaN
#
#          competitor8_rate  competitor8_has_availability  \
# 2380552               NaN                           NaN
# 2380553               0.0                           0.0
# 2380554               0.0                           0.0
# 2380555               0.0                           0.0
# 2380556               NaN                           1.0
#
#          competitor8_price_percent_diff  clicked  booking_value  booked
# 2380552                             NaN        0            NaN       0
# 2380553                             NaN        0            NaN       0
# 2380554                             NaN        0            NaN       0
# 2380555                             NaN        0            NaN       0
# 2380556                             NaN        0            NaN       0
#
# [5 rows x 54 columns]

# %% [markdown]
# ###  No. of Rows and No. of columns

# %%
print("No. of rows = ", df.shape[0])
print("No. of columns = ", df.shape[1])
# Out:
# No. of rows =  2380557
# No. of columns =  54

# %% [markdown]
# ###  Information about data types of each column

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2380557 entries, 0 to 2380556
# Data columns (total 54 columns):
#  #   Column                          Dtype
# ---  ------                          -----
#  0   search_id                       int64
#  1   timestamp                       datetime64[ns]
#  2   site_id                         int64
#  3   user_country_id                 int64
#  4   user_hist_stars                 float64
#  5   user_hist_paid                  float64
#  6   listing_country_id              int64
#  7   listing_id                      int64
#  8   listing_stars                   int64
#  9   listing_review_score            float64
#  10  is_brand                        int64
#  11  location_score1                 float64
#  12  location_score2                 float64
#  13  log_historical_price            float64
#  14  listing_position                int64
#  15  price_usd                       float64
#  16  has_promotion                   int64
#  17  destination_id                  int64
#  18  length_of_stay                  int64
#  19  booking_window                  int64
#  20  num_adults                      int64
#  21  num_kids                        int64
#  22  num_rooms                       int64
#  23  stay_on_saturday                int64
#  24  log_click_proportion            float64
#  25  distance_to_dest                float64
#  26  random_sort                     int64
#  27  competitor1_rate                float64
#  28  competitor1_has_availability    float64
#  29  competitor1_price_percent_diff  float64
#  30  competitor2_rate                float64
#  31  competitor2_has_availability    float64
#  32  competitor2_price_percent_diff  float64
#  33  competitor3_rate                float64
#  34  competitor3_has_availability    float64
#  35  competitor3_price_percent_diff  float64
#  36  competitor4_rate                float64
#  37  competitor4_has_availability    float64
#  38  competitor4_price_percent_diff  float64
#  39  competitor5_rate                float64
#  40  competitor5_has_availability    float64
#  41  competitor5_price_percent_diff  float64
#  42  competitor6_rate                float64
#  43  competitor6_has_availability    float64
#  44  competitor6_price_percent_diff  float64
#  45  competitor7_rate                float64
#  46  competitor7_has_availability    float64
#  47  competitor7_price_percent_diff  float64
#  48  competitor8_rate                float64
#  49  competitor8_has_availability    float64
#  50  competitor8_price_percent_diff  float64
#  51  clicked                         int64
#  52  booking_value                   float64
#  53  booked                          int64
# dtypes: datetime64[ns](1), float64(34), int64(19)
# memory usage: 980.8 MB
# None

# %%
#lets check the null vales without usig visualisation
df.isnull().sum()
#here we can see in above dataset there are  null values present
# Out:
# search_id                               0
# timestamp                               0
# site_id                                 0
# user_country_id                         0
# user_hist_stars                   2257777
# user_hist_paid                    2257063
# listing_country_id                      0
# listing_id                              0
# listing_stars                           0
# listing_review_score                 3486
# is_brand                                0
# location_score1                         0
# location_score2                    525992
# log_historical_price                    0
# listing_position                        0
# price_usd                               0
# has_promotion                           0
# destination_id                          0
# length_of_stay                          0
# booking_window                          0
# num_adults                              0
# num_kids                                0
# num_rooms                               0
# stay_on_saturday                        0
# log_click_proportion              2228450
# distance_to_dest                   770336
# random_sort                             0
# competitor1_rate                  2321547
# competitor1_has_availability      2316895
# competitor1_price_percent_diff    2334156
# competitor2_rate                  1414799
# competitor2_has_availability      1364441
# competitor2_price_percent_diff    2116587
# competitor3_rate                  1649006
# competitor3_has_availability      1592471
# competitor3_price_percent_diff    2155071
# competitor4_rate                  2232363
# competitor4_has_availability      2215276
# competitor4_price_percent_diff    2317696
# competitor5_rate                  1315475
# competitor5_has_availability      1249117
# competitor5_price_percent_diff    1979393
# competitor6_rate                  2260920
# competitor6_has_availability      2250665
# competitor6_price_percent_diff    2332596
# competitor7_rate                  2226089
# competitor7_has_availability      2205707
# competitor7_price_percent_diff    2312725
# competitor8_rate                  1467062
# competitor8_has_availability      1433092
# competitor8_price_percent_diff    2087857
# clicked                                 0
# booking_value                     2314169
# booked                                  0
# dtype: int64

# %% [markdown]
# Finding:
#     1. 2380557 row with 54 features in this dataset.
#     2. Null Value present in the dataset.
#     3.  More null value present in All competitor features with respect to OTA.
#     4. No any object type features in this datset and 34 is float type and 19 features is int type.
#     5. At the time of EDA process change the date type of feture realted to our vale.

# %% [markdown]
# ### b.	Perform summary statistics and explain what issues these statistics reveal.

# %% [markdown]
# ## Summary Statistics

# %%
df.describe()
# Out:
#           search_id       site_id  user_country_id  user_hist_stars  \
# count  2.380557e+06  2.380557e+06     2.380557e+06    122780.000000
# mean   3.337016e+05  9.970224e+00     1.754588e+02         3.382814
# std    1.923719e+05  7.667827e+00     6.585934e+01         0.694562
# min    4.000000e+00  1.000000e+00     1.000000e+00         1.500000
# 25%    1.674260e+05  5.000000e+00     1.000000e+02         2.950000
# 50%    3.332720e+05  5.000000e+00     2.190000e+02         3.450000
# 75%    5.007050e+05  1.400000e+01     2.190000e+02         3.950000
# max    6.655730e+05  3.400000e+01     2.310000e+02         5.000000
#
#        user_hist_paid  listing_country_id    listing_id  listing_stars  \
# count   123494.000000        2.380557e+06  2.380557e+06   2.380557e+06
# mean       178.094940        1.739159e+02  7.008190e+04   3.180607e+00
# std        108.568025        6.832483e+01  4.060398e+04   1.052086e+00
# min          0.000000        1.000000e+00  1.000000e+00   0.000000e+00
# 25%        111.090000        1.000000e+02  3.502800e+04   3.000000e+00
# 50%        152.620000        2.190000e+02  6.961500e+04   3.000000e+00
# 75%        215.950000        2.190000e+02  1.051420e+05   4.000000e+00
# max       1507.120000        2.300000e+02  1.408210e+05   5.000000e+00
#
#        listing_review_score      is_brand  ...  \
# count          2.377071e+06  2.380557e+06  ...
# mean           3.779416e+00  6.346880e-01  ...
# std            1.049727e+00  4.815176e-01  ...
# min            0.000000e+00  0.000000e+00  ...
# 25%            3.500000e+00  0.000000e+00  ...
# 50%            4.000000e+00  1.000000e+00  ...
# 75%            4.500000e+00  1.000000e+00  ...
# max            5.000000e+00  1.000000e+00  ...
#
#        competitor6_price_percent_diff  competitor7_rate  \
# count                    47961.000000     154468.000000
# mean                        17.196243          0.147856
# std                         29.536009          0.579293
# min                          2.000000         -1.000000
# 25%                          6.000000          0.000000
# 50%                         11.000000          0.000000
# 75%                         18.000000          1.000000
# max                       1363.000000          1.000000
#
#        competitor7_has_availability  competitor7_price_percent_diff  \
# count                 174850.000000                    67832.000000
# mean                       0.083180                       20.109919
# std                        0.317575                       63.110961
# min                       -1.000000                        2.000000
# 25%                        0.000000                        7.000000
# 50%                        0.000000                       12.000000
# 75%                        0.000000                       20.000000
# max                        1.000000                     7951.000000
#
#        competitor8_rate  competitor8_has_availability  \
# count     913495.000000                 947465.000000
# mean          -0.060010                      0.009595
# std            0.469455                      0.203876
# min           -1.000000                     -1.000000
# 25%            0.000000                      0.000000
# 50%            0.000000                      0.000000
# 75%            0.000000                      0.000000
# max            1.000000                      1.000000
#
#        competitor8_price_percent_diff       clicked  booking_value  \
# count                   292700.000000  2.380557e+06   66388.000000
# mean                        21.731093  4.456688e-02     383.229069
# std                        800.608005  2.063509e-01     527.019882
# min                          2.000000  0.000000e+00       0.000000
# 25%                          7.000000  0.000000e+00     124.150000
# 50%                         11.000000  0.000000e+00     219.185000
# 75%                         17.000000  0.000000e+00     432.125000
# max                     130000.000000  1.000000e+00   20238.720000
#
#              booked
# count  2.380557e+06
# mean   2.788759e-02
# std    1.646508e-01
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    0.000000e+00
# max    1.000000e+00
#
# [8 rows x 53 columns]

# %% [markdown]
# Observation:
#     1. mean is greater than median in maxium features features. means maxiu features have right skewed
#     2. In somefeatures Difference between 75% and max is very huge so maximun features have lots of outliers.

# %%
#Seprate the categorical columns and Numerical columns
cat_df,num_df=[],[]

for i in df:
    if df[i].dtype=='O':
        cat_df.append(i)
    elif (df[i].dtypes=='int64') | (df[i].dtypes=='float64') | (df[i].dtypes=='int32'):
        num_df.append(i)
    else: continue
        
print('>>> Total Number of Feature::', df.shape[1])
print('>>> Number of categorical features::', len(cat_df))
print('>>> Number of Numerical Feature::', len(num_df))
# Out:
# >>> Total Number of Feature:: 54
# >>> Number of categorical features:: 0
# >>> Number of Numerical Feature:: 53

# %%
#univariate analysis of numerical feature
for i in num_df:
    f=plt.figure(figsize=(17,3))
    f.add_subplot(1,2,1)
    sns.distplot(df[i].describe())
    f.add_subplot(1,2,2)
    sns.boxplot(df[i])

# %%
df.hist(figsize=(20,20))
plt.show()

# %% [markdown]
# Observation:
#     1. Lots of outliers present in maximum features.
#     2. Maximum faetures are right skewed and no any feature is left skewed.
#     3. destination_id,listing_id and search_id is likely to be a unique identifier for employees given the feature's quasi-uniform distribution
#     4.  Some features are constant values for all booking. They're likely to be redundant features.
#     5. Several distributions are right-skewed

# %% [markdown]
# ### c.	Perform exploratory analysis to identify any collinearities and explain which issues collinearity causes.

# %%
#Check Correlation
df.corr()
# Out:
#                                 search_id   site_id  user_country_id  \
# search_id                        1.000000  0.003338        -0.000633
# site_id                          0.003338  1.000000        -0.304867
# user_country_id                 -0.000633 -0.304867         1.000000
# user_hist_stars                 -0.000741  0.307889        -0.254607
# user_hist_paid                  -0.021676  0.083580        -0.061223
# listing_country_id              -0.001352 -0.316166         0.475955
# listing_id                      -0.000353  0.003156         0.000759
# listing_stars                    0.000264  0.173546        -0.111548
# listing_review_score            -0.000069 -0.072936         0.062330
# is_brand                        -0.001236 -0.198551         0.182769
# location_score1                  0.001658  0.179594        -0.125767
# location_score2                 -0.002855  0.064470        -0.016222
# log_historical_price            -0.001783  0.023578        -0.018009
# listing_position                 0.002956 -0.031008         0.017506
# price_usd                       -0.002613 -0.001891         0.000112
# has_promotion                    0.001311  0.083838        -0.033014
# destination_id                  -0.000872  0.020703        -0.002611
# length_of_stay                  -0.000680  0.107595        -0.098039
# booking_window                   0.002611  0.173011        -0.086305
# num_adults                       0.002328 -0.019009         0.004711
# num_kids                        -0.003353 -0.040890         0.012882
# num_rooms                       -0.004294  0.025075        -0.027814
# stay_on_saturday                 0.002088 -0.080444         0.065441
# log_click_proportion            -0.000766  0.063754         0.028159
# distance_to_dest                 0.005886  0.347429        -0.061436
# random_sort                     -0.001303  0.023869        -0.035113
# competitor1_rate                -0.001731  0.015974        -0.003522
# competitor1_has_availability    -0.001104 -0.004186         0.000968
# competitor1_price_percent_diff   0.002704  0.056979        -0.096156
# competitor2_rate                 0.001654  0.049452        -0.026659
# competitor2_has_availability     0.000289  0.008568        -0.009236
# competitor2_price_percent_diff   0.000953  0.004645         0.000456
# competitor3_rate                 0.000745  0.036206        -0.022616
# competitor3_has_availability    -0.000184  0.055989        -0.040318
# competitor3_price_percent_diff  -0.001455  0.000076        -0.002936
# competitor4_rate                 0.003701 -0.016667         0.018902
# competitor4_has_availability    -0.001258 -0.096615         0.052196
# competitor4_price_percent_diff  -0.009624 -0.020598         0.009703
# competitor5_rate                 0.000726 -0.019669         0.024301
# competitor5_has_availability     0.002499 -0.017784         0.023060
# competitor5_price_percent_diff  -0.003097 -0.000071        -0.002712
# competitor6_rate                -0.001772 -0.000279         0.002716
# competitor6_has_availability     0.000794 -0.011374         0.002433
# competitor6_price_percent_diff   0.006069 -0.001176        -0.012217
# competitor7_rate                 0.004199  0.003143        -0.001957
# competitor7_has_availability    -0.003893 -0.021009        -0.006318
# competitor7_price_percent_diff   0.002156 -0.003627        -0.016298
# competitor8_rate                 0.001695  0.015761        -0.017937
# competitor8_has_availability    -0.000787 -0.007528         0.012186
# competitor8_price_percent_diff   0.000319 -0.000828         0.000831
# clicked                         -0.000719  0.008371        -0.004951
# booking_value                   -0.003377  0.087384        -0.072842
# booked                          -0.000324 -0.000576         0.002178
#
#                                 user_hist_stars  user_hist_paid  \
# search_id                             -0.000741       -0.021676
# site_id                                0.307889        0.083580
# user_country_id                       -0.254607       -0.061223
# user_hist_stars                        1.000000        0.487225
# user_hist_paid                         0.487225        1.000000
# listing_country_id                    -0.301045       -0.069117
# listing_id                             0.008177       -0.003065
# listing_stars                          0.279543        0.145106
# listing_review_score                   0.000278        0.046773
# is_brand                              -0.190238       -0.056761
# location_score1                        0.259366        0.152373
# location_score2                        0.059883        0.035215
# log_historical_price                   0.077023        0.040763
# listing_position                      -0.014370       -0.014426
# price_usd                              0.178169        0.185226
# has_promotion                          0.087977        0.045579
# destination_id                        -0.010702       -0.030822
# length_of_stay                         0.072050        0.078088
# booking_window                         0.089112        0.105317
# num_adults                            -0.026011        0.014684
# num_kids                               0.012279        0.063668
# num_rooms                              0.009203        0.000695
# stay_on_saturday                      -0.008735       -0.004695
# log_click_proportion                  -0.016602        0.014915
# distance_to_dest                       0.281867        0.162109
# random_sort                            0.009415        0.025464
# competitor1_rate                      -0.020711        0.020488
# competitor1_has_availability           0.021245       -0.021678
# competitor1_price_percent_diff        -0.068526       -0.057275
# competitor2_rate                       0.035002        0.000761
# competitor2_has_availability           0.024932        0.023064
# competitor2_price_percent_diff         0.020272       -0.000327
# competitor3_rate                       0.040056       -0.009931
# competitor3_has_availability           0.040726       -0.016785
# competitor3_price_percent_diff         0.010417        0.009559
# competitor4_rate                      -0.023272        0.011023
# competitor4_has_availability          -0.028897        0.049691
# competitor4_price_percent_diff        -0.063644        0.000429
# competitor5_rate                      -0.015781       -0.001823
# competitor5_has_availability          -0.022554       -0.026166
# competitor5_price_percent_diff         0.010274        0.014567
# competitor6_rate                      -0.005714       -0.005862
# competitor6_has_availability          -0.001355        0.009578
# competitor6_price_percent_diff        -0.000537       -0.013489
# competitor7_rate                       0.003156        0.009881
# competitor7_has_availability           0.026186        0.003239
# competitor7_price_percent_diff         0.007809       -0.008130
# competitor8_rate                       0.044701        0.018274
# competitor8_has_availability          -0.018056       -0.015989
# competitor8_price_percent_diff         0.000671        0.001329
# clicked                                0.001130        0.001298
# booking_value                          0.214766        0.326537
# booked                                -0.000805       -0.000306
#
#                                 listing_country_id  listing_id  listing_stars  \
# search_id                                -0.001352   -0.000353       0.000264
# site_id                                  -0.316166    0.003156       0.173546
# user_country_id                           0.475955    0.000759      -0.111548
# user_hist_stars                          -0.301045    0.008177       0.279543
# user_hist_paid                           -0.069117   -0.003065       0.145106
# listing_country_id                        1.000000   -0.000912      -0.163322
# listing_id                               -0.000912    1.000000       0.003125
# listing_stars                            -0.163322    0.003125       1.000000
# listing_review_score                      0.091492   -0.000409       0.304868
# is_brand                                  0.313086    0.001046       0.021530
# location_score1                          -0.190321   -0.004222       0.286722
# location_score2                          -0.033549   -0.002386       0.085580
# log_historical_price                     -0.023944   -0.001675       0.167386
# listing_position                          0.029805   -0.000758      -0.106520
# price_usd                                -0.005523    0.000142       0.008934
# has_promotion                            -0.041516    0.002475       0.173341
# destination_id                           -0.016077   -0.004207      -0.005160
# length_of_stay                           -0.084760    0.001568       0.089774
# booking_window                           -0.111895   -0.000995       0.074635
# num_adults                                0.029754   -0.000733       0.008277
# num_kids                                  0.053629   -0.001235      -0.031002
# num_rooms                                -0.014131   -0.000235       0.038510
# stay_on_saturday                          0.073588    0.000345      -0.041229
# log_click_proportion                      0.014772   -0.007050       0.038798
# distance_to_dest                         -0.372571    0.003113       0.185877
# random_sort                              -0.028674    0.002142      -0.009450
# competitor1_rate                         -0.117442    0.007583       0.043874
# competitor1_has_availability             -0.019858   -0.005849      -0.056873
# competitor1_price_percent_diff           -0.078292   -0.005509      -0.029447
# competitor2_rate                         -0.051075    0.004293      -0.017309
# competitor2_has_availability             -0.015176    0.002557       0.006354
# competitor2_price_percent_diff           -0.000514   -0.003017       0.003745
# competitor3_rate                         -0.058703   -0.001210      -0.015238
# competitor3_has_availability             -0.067060    0.001741      -0.013221
# competitor3_price_percent_diff           -0.004327   -0.004225       0.016175
# competitor4_rate                          0.031898    0.002435       0.010490
# competitor4_has_availability              0.125544   -0.023687      -0.042100
# competitor4_price_percent_diff            0.019586   -0.012903       0.008659
# competitor5_rate                          0.032551    0.001578       0.017628
# competitor5_has_availability              0.030676   -0.000925      -0.027427
# competitor5_price_percent_diff           -0.003100   -0.000403       0.009590
# competitor6_rate                         -0.016825   -0.004304      -0.016975
# competitor6_has_availability             -0.029338    0.005798      -0.037026
# competitor6_price_percent_diff           -0.035843    0.011076      -0.027103
# competitor7_rate                         -0.002624   -0.006031      -0.015933
# competitor7_has_availability             -0.065033   -0.003361      -0.033033
# competitor7_price_percent_diff           -0.018132    0.010853      -0.011550
# competitor8_rate                         -0.036254    0.002792       0.037437
# competitor8_has_availability              0.012347    0.005073      -0.029524
# competitor8_price_percent_diff           -0.001307   -0.002888       0.015840
# clicked                                  -0.006302   -0.000465       0.031012
# booking_value                            -0.091785   -0.008185       0.258911
# booked                                    0.000763   -0.000282       0.022089
#
#                                 listing_review_score  is_brand  ...  \
# search_id                                  -0.000069 -0.001236  ...
# site_id                                    -0.072936 -0.198551  ...
# user_country_id                             0.062330  0.182769  ...
# user_hist_stars                             0.000278 -0.190238  ...
# user_hist_paid                              0.046773 -0.056761  ...
# listing_country_id                          0.091492  0.313086  ...
# listing_id                                 -0.000409  0.001046  ...
# listing_stars                               0.304868  0.021530  ...
# listing_review_score                        1.000000  0.202763  ...
# is_brand                                    0.202763  1.000000  ...
# location_score1                             0.110763 -0.189140  ...
# location_score2                             0.053868 -0.088217  ...
# log_historical_price                        0.120120 -0.001951  ...
# listing_position                           -0.054356  0.022010  ...
# price_usd                                   0.001273 -0.000711  ...
# has_promotion                               0.057401 -0.117088  ...
# destination_id                             -0.007321 -0.026555  ...
# length_of_stay                             -0.019733 -0.106472  ...
# booking_window                              0.008359 -0.094593  ...
# num_adults                                  0.022200  0.008796  ...
# num_kids                                    0.018240  0.040364  ...
# num_rooms                                   0.017832  0.021403  ...
# stay_on_saturday                            0.020717  0.073669  ...
# log_click_proportion                        0.041163 -0.028558  ...
# distance_to_dest                           -0.051736 -0.210296  ...
# random_sort                                -0.051571 -0.043400  ...
# competitor1_rate                            0.065405 -0.112107  ...
# competitor1_has_availability               -0.030301 -0.019301  ...
# competitor1_price_percent_diff             -0.005248  0.001069  ...
# competitor2_rate                           -0.017451 -0.095742  ...
# competitor2_has_availability                0.008152 -0.062963  ...
# competitor2_price_percent_diff             -0.001363 -0.003879  ...
# competitor3_rate                           -0.018210 -0.076882  ...
# competitor3_has_availability               -0.049043 -0.102746  ...
# competitor3_price_percent_diff              0.008915  0.001365  ...
# competitor4_rate                            0.060040  0.005554  ...
# competitor4_has_availability                0.023252  0.007340  ...
# competitor4_price_percent_diff              0.010551  0.009699  ...
# competitor5_rate                            0.045998  0.057263  ...
# competitor5_has_availability               -0.008274 -0.002455  ...
# competitor5_price_percent_diff              0.003612 -0.001903  ...
# competitor6_rate                           -0.005040 -0.000271  ...
# competitor6_has_availability               -0.009978 -0.058934  ...
# competitor6_price_percent_diff             -0.024589 -0.098406  ...
# competitor7_rate                           -0.011839 -0.002987  ...
# competitor7_has_availability                0.001712 -0.057431  ...
# competitor7_price_percent_diff             -0.016191 -0.038277  ...
# competitor8_rate                            0.067580 -0.012788  ...
# competitor8_has_availability               -0.005990 -0.056603  ...
# competitor8_price_percent_diff              0.007876  0.000817  ...
# clicked                                     0.024103  0.001456  ...
# booking_value                               0.112661 -0.047881  ...
# booked                                      0.025697  0.009751  ...
#
#                                 competitor6_price_percent_diff  \
# search_id                                             0.006069
# site_id                                              -0.001176
# user_country_id                                      -0.012217
# user_hist_stars                                      -0.000537
# user_hist_paid                                       -0.013489
# listing_country_id                                   -0.035843
# listing_id                                            0.011076
# listing_stars                                        -0.027103
# listing_review_score                                 -0.024589
# is_brand                                             -0.098406
# location_score1                                       0.014645
# location_score2                                       0.005182
# log_historical_price                                 -0.014682
# listing_position                                      0.006753
# price_usd                                             0.015673
# has_promotion                                         0.004377
# destination_id                                        0.016469
# length_of_stay                                        0.000203
# booking_window                                       -0.014392
# num_adults                                           -0.003974
# num_kids                                             -0.000300
# num_rooms                                            -0.017472
# stay_on_saturday                                     -0.004787
# log_click_proportion                                 -0.004141
# distance_to_dest                                      0.000008
# random_sort                                           0.005135
# competitor1_rate                                      0.002501
# competitor1_has_availability                          0.002868
# competitor1_price_percent_diff                       -0.006552
# competitor2_rate                                      0.035953
# competitor2_has_availability                          0.087345
# competitor2_price_percent_diff                        0.229221
# competitor3_rate                                      0.051030
# competitor3_has_availability                          0.077693
# competitor3_price_percent_diff                       -0.010152
# competitor4_rate                                      0.019873
# competitor4_has_availability                         -0.029434
# competitor4_price_percent_diff                        0.204372
# competitor5_rate                                      0.044694
# competitor5_has_availability                          0.013069
# competitor5_price_percent_diff                        0.019246
# competitor6_rate                                      0.077151
# competitor6_has_availability                          0.021239
# competitor6_price_percent_diff                        1.000000
# competitor7_rate                                      0.036883
# competitor7_has_availability                          0.040022
# competitor7_price_percent_diff                        0.348861
# competitor8_rate                                      0.069311
# competitor8_has_availability                          0.001625
# competitor8_price_percent_diff                        0.542476
# clicked                                              -0.001227
# booking_value                                        -0.014725
# booked                                               -0.001406
#
#                                 competitor7_rate  \
# search_id                               0.004199
# site_id                                 0.003143
# user_country_id                        -0.001957
# user_hist_stars                         0.003156
# user_hist_paid                          0.009881
# listing_country_id                     -0.002624
# listing_id                             -0.006031
# listing_stars                          -0.015933
# listing_review_score                   -0.011839
# is_brand                               -0.002987
# location_score1                        -0.004403
# location_score2                        -0.002143
# log_historical_price                    0.015167
# listing_position                       -0.021781
# price_usd                              -0.001846
# has_promotion                           0.053679
# destination_id                         -0.018396
# length_of_stay                          0.004236
# booking_window                          0.018023
# num_adults                              0.003733
# num_kids                                0.002556
# num_rooms                              -0.010070
# stay_on_saturday                       -0.000717
# log_click_proportion                    0.008141
# distance_to_dest                        0.015586
# random_sort                            -0.007689
# competitor1_rate                        0.184214
# competitor1_has_availability           -0.015089
# competitor1_price_percent_diff          0.027807
# competitor2_rate                        0.319118
# competitor2_has_availability           -0.016986
# competitor2_price_percent_diff          0.125991
# competitor3_rate                        0.108051
# competitor3_has_availability            0.024648
# competitor3_price_percent_diff         -0.005722
# competitor4_rate                        0.265722
# competitor4_has_availability           -0.023120
# competitor4_price_percent_diff         -0.002818
# competitor5_rate                        0.330565
# competitor5_has_availability           -0.011362
# competitor5_price_percent_diff         -0.007056
# competitor6_rate                        0.509128
# competitor6_has_availability            0.008408
# competitor6_price_percent_diff          0.036883
# competitor7_rate                        1.000000
# competitor7_has_availability            0.004218
# competitor7_price_percent_diff          0.068645
# competitor8_rate                        0.132450
# competitor8_has_availability            0.015933
# competitor8_price_percent_diff          0.045881
# clicked                                 0.013596
# booking_value                          -0.023626
# booked                                  0.010733
#
#                                 competitor7_has_availability  \
# search_id                                          -0.003893
# site_id                                            -0.021009
# user_country_id                                    -0.006318
# user_hist_stars                                     0.026186
# user_hist_paid                                      0.003239
# listing_country_id                                 -0.065033
# listing_id                                         -0.003361
# listing_stars                                      -0.033033
# listing_review_score                                0.001712
# is_brand                                           -0.057431
# location_score1                                     0.037124
# location_score2                                     0.029972
# log_historical_price                               -0.008904
# listing_position                                   -0.002917
# price_usd                                           0.003681
# has_promotion                                      -0.009343
# destination_id                                      0.011811
# length_of_stay                                     -0.017177
# booking_window                                     -0.007092
# num_adults                                          0.003456
# num_kids                                           -0.006010
# num_rooms                                          -0.009939
# stay_on_saturday                                    0.010185
# log_click_proportion                               -0.046786
# distance_to_dest                                    0.017398
# random_sort                                         0.003306
# competitor1_rate                                   -0.011826
# competitor1_has_availability                        0.272401
# competitor1_price_percent_diff                     -0.003732
# competitor2_rate                                   -0.015830
# competitor2_has_availability                        0.100405
# competitor2_price_percent_diff                     -0.025252
# competitor3_rate                                   -0.004703
# competitor3_has_availability                        0.102240
# competitor3_price_percent_diff                      0.063609
# competitor4_rate                                   -0.052081
# competitor4_has_availability                        0.157351
# competitor4_price_percent_diff                     -0.021256
# competitor5_rate                                    0.007670
# competitor5_has_availability                        0.236787
# competitor5_price_percent_diff                      0.021727
# competitor6_rate                                    0.009536
# competitor6_has_availability                        0.382977
# competitor6_price_percent_diff                      0.040022
# competitor7_rate                                    0.004218
# competitor7_has_availability                        1.000000
# competitor7_price_percent_diff                      0.002103
# competitor8_rate                                   -0.017775
# competitor8_has_availability                        0.104348
# competitor8_price_percent_diff                      0.056857
# clicked                                            -0.006616
# booking_value                                       0.020345
# booked                                             -0.005397
#
#                                 competitor7_price_percent_diff  \
# search_id                                             0.002156
# site_id                                              -0.003627
# user_country_id                                      -0.016298
# user_hist_stars                                       0.007809
# user_hist_paid                                       -0.008130
# listing_country_id                                   -0.018132
# listing_id                                            0.010853
# listing_stars                                        -0.011550
# listing_review_score                                 -0.016191
# is_brand                                             -0.038277
# location_score1                                      -0.006562
# location_score2                                      -0.007562
# log_historical_price                                  0.000483
# listing_position                                     -0.005984
# price_usd                                             0.003842
# has_promotion                                        -0.009956
# destination_id                                       -0.007753
# length_of_stay                                       -0.004263
# booking_window                                        0.002565
# num_adults                                           -0.002700
# num_kids                                             -0.004454
# num_rooms                                            -0.001869
# stay_on_saturday                                     -0.002715
# log_click_proportion                                 -0.039446
# distance_to_dest                                      0.014926
# random_sort                                           0.006233
# competitor1_rate                                      0.022232
# competitor1_has_availability                         -0.005002
# competitor1_price_percent_diff                       -0.001120
# competitor2_rate                                      0.085488
# competitor2_has_availability                          0.098599
# competitor2_price_percent_diff                        0.145558
# competitor3_rate                                      0.025545
# competitor3_has_availability                          0.051209
# competitor3_price_percent_diff                        0.016729
# competitor4_rate                                      0.071402
# competitor4_has_availability                          0.011168
# competitor4_price_percent_diff                        0.134310
# competitor5_rate                                      0.026640
# competitor5_has_availability                          0.005211
# competitor5_price_percent_diff                        0.006543
# competitor6_rate                                      0.019172
# competitor6_has_availability                          0.013279
# competitor6_price_percent_diff                        0.348861
# competitor7_rate                                      0.068645
# competitor7_has_availability                          0.002103
# competitor7_price_percent_diff                        1.000000
# competitor8_rate                                      0.029604
# competitor8_has_availability                          0.049202
# competitor8_price_percent_diff                        0.289792
# clicked                                               0.002955
# booking_value                                        -0.044523
# booked                                                0.001914
#
#                                 competitor8_rate  \
# search_id                               0.001695
# site_id                                 0.015761
# user_country_id                        -0.017937
# user_hist_stars                         0.044701
# user_hist_paid                          0.018274
# listing_country_id                     -0.036254
# listing_id                              0.002792
# listing_stars                           0.037437
# listing_review_score                    0.067580
# is_brand                               -0.012788
# location_score1                         0.013825
# location_score2                         0.013074
# log_historical_price                    0.008287
# listing_position                       -0.027211
# price_usd                              -0.000439
# has_promotion                           0.097574
# destination_id                         -0.000629
# length_of_stay                          0.003343
# booking_window                         -0.008584
# num_adults                             -0.005343
# num_kids                               -0.001796
# num_rooms                              -0.002492
# stay_on_saturday                       -0.012576
# log_click_proportion                    0.002757
# distance_to_dest                        0.010149
# random_sort                            -0.012290
# competitor1_rate                        0.437739
# competitor1_has_availability            0.018782
# competitor1_price_percent_diff          0.038443
# competitor2_rate                        0.478205
# competitor2_has_availability           -0.004847
# competitor2_price_percent_diff          0.090921
# competitor3_rate                        0.466609
# competitor3_has_availability            0.000229
# competitor3_price_percent_diff          0.002117
# competitor4_rate                        0.493767
# competitor4_has_availability            0.013008
# competitor4_price_percent_diff         -0.000109
# competitor5_rate                        0.636241
# competitor5_has_availability            0.007415
# competitor5_price_percent_diff          0.006286
# competitor6_rate                        0.084685
# competitor6_has_availability            0.024980
# competitor6_price_percent_diff          0.069311
# competitor7_rate                        0.132450
# competitor7_has_availability           -0.017775
# competitor7_price_percent_diff          0.029604
# competitor8_rate                        1.000000
# competitor8_has_availability            0.005503
# competitor8_price_percent_diff          0.007319
# clicked                                 0.023790
# booking_value                          -0.012068
# booked                                  0.024254
#
#                                 competitor8_has_availability  \
# search_id                                          -0.000787
# site_id                                            -0.007528
# user_country_id                                     0.012186
# user_hist_stars                                    -0.018056
# user_hist_paid                                     -0.015989
# listing_country_id                                  0.012347
# listing_id                                          0.005073
# listing_stars                                      -0.029524
# listing_review_score                               -0.005990
# is_brand                                           -0.056603
# location_score1                                    -0.005655
# location_score2                                     0.004386
# log_historical_price                               -0.003501
# listing_position                                   -0.009824
# price_usd                                           0.004554
# has_promotion                                      -0.004524
# destination_id                                      0.003400
# length_of_stay                                     -0.015782
# booking_window                                     -0.001202
# num_adults                                         -0.000918
# num_kids                                           -0.004837
# num_rooms                                          -0.004105
# stay_on_saturday                                    0.003161
# log_click_proportion                               -0.008112
# distance_to_dest                                   -0.002149
# random_sort                                        -0.004633
# competitor1_rate                                    0.006813
# competitor1_has_availability                        0.317064
# competitor1_price_percent_diff                     -0.144489
# competitor2_rate                                    0.007089
# competitor2_has_availability                        0.370722
# competitor2_price_percent_diff                      0.015414
# competitor3_rate                                    0.004870
# competitor3_has_availability                        0.302667
# competitor3_price_percent_diff                      0.006573
# competitor4_rate                                    0.013591
# competitor4_has_availability                        0.216176
# competitor4_price_percent_diff                      0.002256
# competitor5_rate                                   -0.000573
# competitor5_has_availability                        0.406308
# competitor5_price_percent_diff                      0.019107
# competitor6_rate                                    0.013071
# competitor6_has_availability                        0.088108
# competitor6_price_percent_diff                      0.001625
# competitor7_rate                                    0.015933
# competitor7_has_availability                        0.104348
# competitor7_price_percent_diff                      0.049202
# competitor8_rate                                    0.005503
# competitor8_has_availability                        1.000000
# competitor8_price_percent_diff                     -0.001360
# clicked                                             0.002484
# booking_value                                      -0.001957
# booked                                              0.001534
#
#                                 competitor8_price_percent_diff   clicked  \
# search_id                                             0.000319 -0.000719
# site_id                                              -0.000828  0.008371
# user_country_id                                       0.000831 -0.004951
# user_hist_stars                                       0.000671  0.001130
# user_hist_paid                                        0.001329  0.001298
# listing_country_id                                   -0.001307 -0.006302
# listing_id                                           -0.002888 -0.000465
# listing_stars                                         0.015840  0.031012
# listing_review_score                                  0.007876  0.024103
# is_brand                                              0.000817  0.001456
# location_score1                                       0.013372  0.002346
# location_score2                                       0.003934  0.073718
# log_historical_price                                  0.004989  0.003157
# listing_position                                      0.001557 -0.165024
# price_usd                                             0.000739  0.000171
# has_promotion                                        -0.002909  0.040241
# destination_id                                       -0.004963  0.000969
# length_of_stay                                        0.000850  0.002308
# booking_window                                       -0.004592  0.001457
# num_adults                                           -0.000473  0.004768
# num_kids                                             -0.003499  0.006132
# num_rooms                                             0.001970  0.007526
# stay_on_saturday                                     -0.003592  0.001820
# log_click_proportion                                  0.002002  0.045062
# distance_to_dest                                      0.004643  0.002219
# random_sort                                           0.001158  0.005218
# competitor1_rate                                     -0.005207  0.013367
# competitor1_has_availability                          0.002453 -0.001196
# competitor1_price_percent_diff                       -0.001886  0.004961
# competitor2_rate                                     -0.000362  0.017189
# competitor2_has_availability                          0.001412 -0.000630
# competitor2_price_percent_diff                        0.027417 -0.000294
# competitor3_rate                                      0.003187  0.017206
# competitor3_has_availability                          0.000664 -0.008044
# competitor3_price_percent_diff                        0.771770 -0.001726
# competitor4_rate                                      0.001634  0.023070
# competitor4_has_availability                          0.008838 -0.000782
# competitor4_price_percent_diff                        0.004402 -0.000032
# competitor5_rate                                      0.002917  0.021439
# competitor5_has_availability                          0.004831 -0.001773
# competitor5_price_percent_diff                        0.340483 -0.001474
# competitor6_rate                                      0.061353  0.015010
# competitor6_has_availability                          0.037214 -0.006253
# competitor6_price_percent_diff                        0.542476 -0.001227
# competitor7_rate                                      0.045881  0.013596
# competitor7_has_availability                          0.056857 -0.006616
# competitor7_price_percent_diff                        0.289792  0.002955
# competitor8_rate                                      0.007319  0.023790
# competitor8_has_availability                         -0.001360  0.002484
# competitor8_price_percent_diff                        1.000000 -0.001558
# clicked                                              -0.001558  1.000000
# booking_value                                        -0.004973       NaN
# booked                                               -0.001186  0.784226
#
#                                 booking_value    booked
# search_id                           -0.003377 -0.000324
# site_id                              0.087384 -0.000576
# user_country_id                     -0.072842  0.002178
# user_hist_stars                      0.214766 -0.000805
# user_hist_paid                       0.326537 -0.000306
# listing_country_id                  -0.091785  0.000763
# listing_id                          -0.008185 -0.000282
# listing_stars                        0.258911  0.022089
# listing_review_score                 0.112661  0.025697
# is_brand                            -0.047881  0.009751
# location_score1                      0.217793 -0.003360
# location_score2                      0.017343  0.066700
# log_historical_price                 0.096350 -0.000224
# listing_position                     0.008700 -0.148420
# price_usd                            0.010995 -0.000026
# has_promotion                        0.070862  0.036804
# destination_id                      -0.010432  0.000327
# length_of_stay                       0.614097 -0.024309
# booking_window                       0.206734 -0.019652
# num_adults                           0.151825 -0.006256
# num_kids                             0.074011  0.004267
# num_rooms                            0.220119  0.007721
# stay_on_saturday                    -0.164935  0.005705
# log_click_proportion                 0.032839  0.026920
# distance_to_dest                     0.217607 -0.003291
# random_sort                         -0.001473 -0.088781
# competitor1_rate                    -0.025638  0.013118
# competitor1_has_availability         0.092753  0.000164
# competitor1_price_percent_diff      -0.078960  0.005091
# competitor2_rate                    -0.022896  0.016101
# competitor2_has_availability         0.017474 -0.000700
# competitor2_price_percent_diff       0.049120 -0.000249
# competitor3_rate                    -0.024589  0.016599
# competitor3_has_availability        -0.011254 -0.008857
# competitor3_price_percent_diff       0.005407 -0.001422
# competitor4_rate                    -0.023898  0.021866
# competitor4_has_availability         0.037667  0.000253
# competitor4_price_percent_diff      -0.012461  0.002543
# competitor5_rate                    -0.022256  0.020527
# competitor5_has_availability         0.007758 -0.002510
# competitor5_price_percent_diff      -0.009520 -0.001142
# competitor6_rate                     0.004796  0.010651
# competitor6_has_availability         0.022976 -0.002835
# competitor6_price_percent_diff      -0.014725 -0.001406
# competitor7_rate                    -0.023626  0.010733
# competitor7_has_availability         0.020345 -0.005397
# competitor7_price_percent_diff      -0.044523  0.001914
# competitor8_rate                    -0.012068  0.024254
# competitor8_has_availability        -0.001957  0.001534
# competitor8_price_percent_diff      -0.004973 -0.001186
# clicked                                   NaN  0.784226
# booking_value                        1.000000       NaN
# booked                                    NaN  1.000000
#
# [53 rows x 53 columns]

# %%
#Check correlation with heatmap
plt.figure(figsize=(28,22))
sns.heatmap(df.corr(),annot=True,fmt='0.0%')

# %% [markdown]
# collinearity causes:
#
# 1. booking_value colleration with clicked and booked is NaN is collinearity causes.
# 2. Clicked and booked is higly correlated

# %% [markdown]
# ## d.	Identify the issues that are encountered in the dataset

# %% [markdown]
# ## DATA CLEANING

# %% [markdown]
# ###  Rows having all missing values

# %%
# Row indexes of empty rows
print("Row indexes of empty rows : ", df[df.isnull().all(axis =1)].index.tolist())
# Out:
# Row indexes of empty rows :  []

# %% [markdown]
# ### Columns having missing values

# %%
print('Columns having missing values are as follows:')
for i in df.isnull().any().index:
    if (df.isnull().any()[i]):
        print(i)
# Out:
# Columns having missing values are as follows:
# user_hist_stars
# user_hist_paid
# listing_review_score
# location_score2
# log_click_proportion
# distance_to_dest
# competitor1_rate
# competitor1_has_availability
# competitor1_price_percent_diff
# competitor2_rate
# competitor2_has_availability
# competitor2_price_percent_diff
# competitor3_rate
# competitor3_has_availability
# competitor3_price_percent_diff
# competitor4_rate
# competitor4_has_availability
# competitor4_price_percent_diff
# competitor5_rate
# competitor5_has_availability
# competitor5_price_percent_diff
# competitor6_rate
# competitor6_has_availability
# competitor6_price_percent_diff
# competitor7_rate
# competitor7_has_availability
# competitor7_price_percent_diff
# competitor8_rate
# competitor8_has_availability
# competitor8_price_percent_diff
# booking_value

# %% [markdown]
# ### Number of missing values and their percentage in each column

# %%
print("Number of missing values in each column:")
print(df.isnull().sum())
print('\nPercentage of missing values in each column:')
print(round(100*df.isnull().sum()/len(df.index)),2)
# Out:
# Number of missing values in each column:
# search_id                               0
# timestamp                               0
# site_id                                 0
# user_country_id                         0
# user_hist_stars                   2257777
# user_hist_paid                    2257063
# listing_country_id                      0
# listing_id                              0
# listing_stars                           0
# listing_review_score                 3486
# is_brand                                0
# location_score1                         0
# location_score2                    525992
# log_historical_price                    0
# listing_position                        0
# price_usd                               0
# has_promotion                           0
# destination_id                          0
# length_of_stay                          0
# booking_window                          0
# num_adults                              0
# num_kids                                0
# num_rooms                               0
# stay_on_saturday                        0
# log_click_proportion              2228450
# distance_to_dest                   770336
# random_sort                             0
# competitor1_rate                  2321547
# competitor1_has_availability      2316895
# competitor1_price_percent_diff    2334156
# competitor2_rate                  1414799
# competitor2_has_availability      1364441
# competitor2_price_percent_diff    2116587
# competitor3_rate                  1649006
# competitor3_has_availability      1592471
# competitor3_price_percent_diff    2155071
# competitor4_rate                  2232363
# competitor4_has_availability      2215276
# competitor4_price_percent_diff    2317696
# competitor5_rate                  1315475
# competitor5_has_availability      1249117
# competitor5_price_percent_diff    1979393
# competitor6_rate                  2260920
# competitor6_has_availability      2250665
# competitor6_price_percent_diff    2332596
# competitor7_rate                  2226089
# competitor7_has_availability      2205707
# competitor7_price_percent_diff    2312725
# competitor8_rate                  1467062
# competitor8_has_availability      1433092
# competitor8_price_percent_diff    2087857
# clicked                                 0
# booking_value                     2314169
# booked                                  0
# dtype: int64
#
# Percentage of missing values in each column:
# search_id                          0.0
# timestamp                          0.0
# site_id                            0.0
# user_country_id                    0.0
# user_hist_stars                   95.0
# user_hist_paid                    95.0
# listing_country_id                 0.0
# listing_id                         0.0
# listing_stars                      0.0
# listing_review_score               0.0
# is_brand                           0.0
# location_score1                    0.0
# location_score2                   22.0
# log_historical_price               0.0
# listing_position                   0.0
# price_usd                          0.0
# has_promotion                      0.0
# destination_id                     0.0
# length_of_stay                     0.0
# booking_window                     0.0
# num_adults                         0.0
# num_kids                           0.0
# num_rooms                          0.0
# stay_on_saturday                   0.0
# log_click_proportion              94.0
# distance_to_dest                  32.0
# random_sort                        0.0
# competitor1_rate                  98.0
# competitor1_has_availability      97.0
# competitor1_price_percent_diff    98.0
# competitor2_rate                  59.0
# competitor2_has_availability      57.0
# competitor2_price_percent_diff    89.0
# competitor3_rate                  69.0
# competitor3_has_availability      67.0
# competitor3_price_percent_diff    91.0
# competitor4_rate                  94.0
# competitor4_has_availability      93.0
# competitor4_price_percent_diff    97.0
# competitor5_rate                  55.0
# competitor5_has_availability      52.0
# competitor5_price_percent_diff    83.0
# competitor6_rate                  95.0
# competitor6_has_availability      95.0
# competitor6_price_percent_diff    98.0
# competitor7_rate                  94.0
# competitor7_has_availability      93.0
# competitor7_price_percent_diff    97.0
# competitor8_rate                  62.0
# competitor8_has_availability      60.0
# competitor8_price_percent_diff    88.0
# clicked                            0.0
# booking_value                     97.0
# booked                             0.0
# dtype: float64 2

# %%
(df.isnull().sum()/len(df))*100>30
# Out:
# search_id                         False
# timestamp                         False
# site_id                           False
# user_country_id                   False
# user_hist_stars                    True
# user_hist_paid                     True
# listing_country_id                False
# listing_id                        False
# listing_stars                     False
# listing_review_score              False
# is_brand                          False
# location_score1                   False
# location_score2                   False
# log_historical_price              False
# listing_position                  False
# price_usd                         False
# has_promotion                     False
# destination_id                    False
# length_of_stay                    False
# booking_window                    False
# num_adults                        False
# num_kids                          False
# num_rooms                         False
# stay_on_saturday                  False
# log_click_proportion               True
# distance_to_dest                   True
# random_sort                       False
# competitor1_rate                   True
# competitor1_has_availability       True
# competitor1_price_percent_diff     True
# competitor2_rate                   True
# competitor2_has_availability       True
# competitor2_price_percent_diff     True
# competitor3_rate                   True
# competitor3_has_availability       True
# competitor3_price_percent_diff     True
# competitor4_rate                   True
# competitor4_has_availability       True
# competitor4_price_percent_diff     True
# competitor5_rate                   True
# competitor5_has_availability       True
# competitor5_price_percent_diff     True
# competitor6_rate                   True
# competitor6_has_availability       True
# competitor6_price_percent_diff     True
# competitor7_rate                   True
# competitor7_has_availability       True
# competitor7_price_percent_diff     True
# competitor8_rate                   True
# competitor8_has_availability       True
# competitor8_price_percent_diff     True
# clicked                           False
# booking_value                      True
# booked                            False
# dtype: bool

# %%
# Removing columns having more than 30% missing values
df = df.drop('user_hist_stars', axis=1)
df = df.drop('user_hist_paid', axis=1)
df = df.drop('log_click_proportion', axis=1)

df = df.drop('distance_to_dest', axis=1)
df = df.drop('competitor1_rate', axis=1)
df = df.drop('competitor1_has_availability', axis=1)
df = df.drop('competitor1_price_percent_diff', axis=1)


df = df.drop('competitor2_rate', axis=1)
df = df.drop('competitor2_has_availability', axis=1)
df = df.drop('competitor2_price_percent_diff', axis=1)


df = df.drop('competitor3_rate', axis=1)
df = df.drop('competitor3_has_availability', axis=1)
df = df.drop('competitor3_price_percent_diff', axis=1)


df = df.drop('competitor4_rate', axis=1)
df = df.drop('competitor4_has_availability', axis=1)
df = df.drop('competitor4_price_percent_diff', axis=1)


df = df.drop('competitor5_rate', axis=1)
df = df.drop('competitor5_has_availability', axis=1)
df = df.drop('competitor5_price_percent_diff', axis=1)


df = df.drop('competitor6_rate', axis=1)
df = df.drop('competitor6_has_availability', axis=1)
df = df.drop('competitor6_price_percent_diff', axis=1)


df = df.drop('competitor7_rate', axis=1)
df = df.drop('competitor7_has_availability', axis=1)
df = df.drop('competitor7_price_percent_diff', axis=1)


df = df.drop('competitor8_rate', axis=1)
df = df.drop('competitor8_has_availability', axis=1)
df = df.drop('competitor8_price_percent_diff', axis=1)

df = df.drop('booking_value', axis=1)

round(100*(df.isnull().sum()/len(df.index)), 2)
# Out:
# search_id                0.00
# timestamp                0.00
# site_id                  0.00
# user_country_id          0.00
# listing_country_id       0.00
# listing_id               0.00
# listing_stars            0.00
# listing_review_score     0.15
# is_brand                 0.00
# location_score1          0.00
# location_score2         22.10
# log_historical_price     0.00
# listing_position         0.00
# price_usd                0.00
# has_promotion            0.00
# destination_id           0.00
# length_of_stay           0.00
# booking_window           0.00
# num_adults               0.00
# num_kids                 0.00
# num_rooms                0.00
# stay_on_saturday         0.00
# random_sort              0.00
# clicked                  0.00
# booked                   0.00
# dtype: float64

# %%
#Lets Check the shape of the dataset
df.shape
# Out:
# (2380557, 25)

# %%
#Lets Check the coulumns name
df.columns
# Out:
# Index(['search_id', 'timestamp', 'site_id', 'user_country_id',
#        'listing_country_id', 'listing_id', 'listing_stars',
#        'listing_review_score', 'is_brand', 'location_score1',
#        'location_score2', 'log_historical_price', 'listing_position',
#        'price_usd', 'has_promotion', 'destination_id', 'length_of_stay',
#        'booking_window', 'num_adults', 'num_kids', 'num_rooms',
#        'stay_on_saturday', 'random_sort', 'clicked', 'booked'],
#       dtype='object')

# %%
#lets check the null vales without usig visualisation
df.isnull().sum()
#here we can see in above dataset there are no null values
# Out:
# search_id                    0
# timestamp                    0
# site_id                      0
# user_country_id              0
# listing_country_id           0
# listing_id                   0
# listing_stars                0
# listing_review_score      3486
# is_brand                     0
# location_score1              0
# location_score2         525992
# log_historical_price         0
# listing_position             0
# price_usd                    0
# has_promotion                0
# destination_id               0
# length_of_stay               0
# booking_window               0
# num_adults                   0
# num_kids                     0
# num_rooms                    0
# stay_on_saturday             0
# random_sort                  0
# clicked                      0
# booked                       0
# dtype: int64

# %% [markdown]
# ### Number of missing values and their percentage in each row

# %%
print(pd.DataFrame.from_dict({'Rows' : df.isnull().any(axis = 1), 
                              'Number of missing values' : df.isnull().sum(axis = 1), 
                              'Percentage of missing values' : round(100*df.isnull().sum(axis = 1)/df.shape[1])})
     )
# Out:
#           Rows  Number of missing values  Percentage of missing values
# 0        False                         0                           0.0
# 1         True                         1                           4.0
# 2        False                         0                           0.0
# 3        False                         0                           0.0
# 4        False                         0                           0.0
# ...        ...                       ...                           ...
# 2380552  False                         0                           0.0
# 2380553  False                         0                           0.0
# 2380554  False                         0                           0.0
# 2380555  False                         0                           0.0
# 2380556  False                         0                           0.0
#
# [2380557 rows x 3 columns]

# %% [markdown]
# ### Number and percentage of rows having more than 5 missing values

# %%
# count the number of rows having > 5 missing values
print("Number of rows having more than 5 missing values : ", len(df[df.isnull().sum(axis=1) > 5].index))
print("Number of rows having more than 5 missing values : ", 100*(len(df[df.isnull().sum(axis=1) > 5].index) / len(df.index)))
# Out:
# Number of rows having more than 5 missing values :  0
# Number of rows having more than 5 missing values :  0.0

# %% [markdown]
# ### Description of data

# %%
df.describe().T
# Out:
#                           count           mean            std  min  \
# search_id             2380557.0  333701.625686  192371.850496  4.0
# site_id               2380557.0       9.970224       7.667827  1.0
# user_country_id       2380557.0     175.458752      65.859339  1.0
# listing_country_id    2380557.0     173.915948      68.324828  1.0
# listing_id            2380557.0   70081.903362   40603.977545  1.0
# listing_stars         2380557.0       3.180607       1.052086  0.0
# listing_review_score  2377071.0       3.779416       1.049727  0.0
# is_brand              2380557.0       0.634688       0.481518  0.0
# location_score1       2380557.0       2.878558       1.536947  0.0
# location_score2       1854565.0       0.131032       0.160594  0.0
# log_historical_price  2380557.0       4.311779       1.842699  0.0
# listing_position      2380557.0      16.867629      10.429703  1.0
# price_usd             2380557.0     291.520316   22882.923196  0.0
# has_promotion         2380557.0       0.214924       0.410769  0.0
# destination_id        2380557.0   14046.417023    8117.353466  2.0
# length_of_stay        2380557.0       2.393825       2.062891  1.0
# booking_window        2380557.0      37.683732      52.114836  0.0
# num_adults            2380557.0       1.969876       0.858077  1.0
# num_kids              2380557.0       0.349146       0.727657  0.0
# num_rooms             2380557.0       1.110318       0.420043  1.0
# stay_on_saturday      2380557.0       0.498266       0.499997  0.0
# random_sort           2380557.0       0.296737       0.456820  0.0
# clicked               2380557.0       0.044567       0.206351  0.0
# booked                2380557.0       0.027888       0.164651  0.0
#
#                               25%          50%         75%          max
# search_id             167426.0000  333272.0000  500705.000    665573.00
# site_id                    5.0000       5.0000      14.000        34.00
# user_country_id          100.0000     219.0000     219.000       231.00
# listing_country_id       100.0000     219.0000     219.000       230.00
# listing_id             35028.0000   69615.0000  105142.000    140821.00
# listing_stars              3.0000       3.0000       4.000         5.00
# listing_review_score       3.5000       4.0000       4.500         5.00
# is_brand                   0.0000       1.0000       1.000         1.00
# location_score1            1.7900       2.7700       4.060         6.98
# location_score2            0.0191       0.0694       0.181         1.00
# log_historical_price       4.4400       4.9100       5.310         6.21
# listing_position           8.0000      16.0000      26.000        40.00
# price_usd                 85.0000     122.2500     185.310  19726328.00
# has_promotion              0.0000       0.0000       0.000         1.00
# destination_id          7115.0000   13539.0000   21118.000     28411.00
# length_of_stay             1.0000       2.0000       3.000        57.00
# booking_window             4.0000      17.0000      49.000       498.00
# num_adults                 2.0000       2.0000       2.000         9.00
# num_kids                   0.0000       0.0000       0.000         9.00
# num_rooms                  1.0000       1.0000       1.000         8.00
# stay_on_saturday           0.0000       0.0000       1.000         1.00
# random_sort                0.0000       0.0000       1.000         1.00
# clicked                    0.0000       0.0000       0.000         1.00
# booked                     0.0000       0.0000       0.000         1.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2380557 entries, 0 to 2380556
# Data columns (total 25 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   search_id             int64
#  1   timestamp             datetime64[ns]
#  2   site_id               int64
#  3   user_country_id       int64
#  4   listing_country_id    int64
#  5   listing_id            int64
#  6   listing_stars         int64
#  7   listing_review_score  float64
#  8   is_brand              int64
#  9   location_score1       float64
#  10  location_score2       float64
#  11  log_historical_price  float64
#  12  listing_position      int64
#  13  price_usd             float64
#  14  has_promotion         int64
#  15  destination_id        int64
#  16  length_of_stay        int64
#  17  booking_window        int64
#  18  num_adults            int64
#  19  num_kids              int64
#  20  num_rooms             int64
#  21  stay_on_saturday      int64
#  22  random_sort           int64
#  23  clicked               int64
#  24  booked                int64
# dtypes: datetime64[ns](1), float64(5), int64(19)
# memory usage: 454.1 MB

# %% [markdown]
# ### Percentage of missing values in each column:

# %%
print(round(100*(df.isnull().sum()/len(df.index)), 2))
# Out:
# search_id                0.00
# timestamp                0.00
# site_id                  0.00
# user_country_id          0.00
# listing_country_id       0.00
# listing_id               0.00
# listing_stars            0.00
# listing_review_score     0.15
# is_brand                 0.00
# location_score1          0.00
# location_score2         22.10
# log_historical_price     0.00
# listing_position         0.00
# price_usd                0.00
# has_promotion            0.00
# destination_id           0.00
# length_of_stay           0.00
# booking_window           0.00
# num_adults               0.00
# num_kids                 0.00
# num_rooms                0.00
# stay_on_saturday         0.00
# random_sort              0.00
# clicked                  0.00
# booked                   0.00
# dtype: float64

# %% [markdown]
# Here we can see that location_score2 column has a significant number of missing values i.e. 22.10%. Let us see the description of this column.

# %%
df['listing_review_score'].describe()
# Out:
# count    2.377071e+06
# mean     3.779416e+00
# std      1.049727e+00
# min      0.000000e+00
# 25%      3.500000e+00
# 50%      4.000000e+00
# 75%      4.500000e+00
# max      5.000000e+00
# Name: listing_review_score, dtype: float64

# %%
df['location_score2'].describe()
# Out:
# count    1.854565e+06
# mean     1.310325e-01
# std      1.605939e-01
# min      0.000000e+00
# 25%      1.910000e-02
# 50%      6.940000e-02
# 75%      1.810000e-01
# max      1.000000e+00
# Name: location_score2, dtype: float64

# %%
df['location_score2'].describe(percentiles = [0.9, 0.95, 0.99])
# Out:
# count    1.854565e+06
# mean     1.310325e-01
# std      1.605939e-01
# min      0.000000e+00
# 50%      6.940000e-02
# 90%      3.527000e-01
# 95%      4.824000e-01
# 99%      7.256000e-01
# max      1.000000e+00
# Name: location_score2, dtype: float64

# %% [markdown]
# In such a case ideally we must impute the values either after outlier removal. But since we do not have to remove outliers in this assignment, we are imputing the missing values by median.

# %%
df['listing_review_score'].fillna(df['listing_review_score'].median(), inplace = True)
df['location_score2'].fillna(df['location_score2'].median(), inplace = True)

# Now lets check the percentage of missing values again
print(round(100*(df.isnull().sum()/len(df.index)), 2))
# Out:
# search_id               0.0
# timestamp               0.0
# site_id                 0.0
# user_country_id         0.0
# listing_country_id      0.0
# listing_id              0.0
# listing_stars           0.0
# listing_review_score    0.0
# is_brand                0.0
# location_score1         0.0
# location_score2         0.0
# log_historical_price    0.0
# listing_position        0.0
# price_usd               0.0
# has_promotion           0.0
# destination_id          0.0
# length_of_stay          0.0
# booking_window          0.0
# num_adults              0.0
# num_kids                0.0
# num_rooms               0.0
# stay_on_saturday        0.0
# random_sort             0.0
# clicked                 0.0
# booked                  0.0
# dtype: float64

# %% [markdown]
# ### Now since all the data cleaning steps have been done. let us check the missing values in whole dataframe

# %%
df.isnull().sum()
# Out:
# search_id               0
# timestamp               0
# site_id                 0
# user_country_id         0
# listing_country_id      0
# listing_id              0
# listing_stars           0
# listing_review_score    0
# is_brand                0
# location_score1         0
# location_score2         0
# log_historical_price    0
# listing_position        0
# price_usd               0
# has_promotion           0
# destination_id          0
# length_of_stay          0
# booking_window          0
# num_adults              0
# num_kids                0
# num_rooms               0
# stay_on_saturday        0
# random_sort             0
# clicked                 0
# booked                  0
# dtype: int64

# %% [markdown]
# ###  Number and percentage of columns removed
# Initial number of columns =54

# %%
print("No. of columns left = ", df.shape[1])
print("No. of columns removed = ", 54 - df.shape[1])
print("Percentage of columns removed = {}%".format(round(100*(54 - df.shape[1])/54,2)))
# Out:
# No. of columns left =  25
# No. of columns removed =  29
# Percentage of columns removed = 53.7%

# %% [markdown]
# ###  Number and percentage of rows removed

# %%
print("No. of Rows left = ", df.shape[0])
print("No. of Rows removed = ", 2380557 - df.shape[0])
print("Percentage of Rows removed = {}%".format(round(100*(2380557 - df.shape[0])/2380557,2)))
# Out:
# No. of Rows left =  2380557
# No. of Rows removed =  0
# Percentage of Rows removed = 0.0%

# %% [markdown]
# ### e.	Propose and implement the solutions for the issues you have found. The issues listed here are not exhaustive. If you encounter any other issues, please propose and implement solutions for those as well.

# %% [markdown]
# In this exercise we got a dataset with a lot of null values and we implemented data cleaning accordingly.:
#     1. For the columns having more than 30% missing values, it will have very less predictive power and we removed it for the sake of simplicity of the model training
#     2. For the rest of the columns, we tried to take help of statistical measure and decided the treatment.
#     3. As a result we lost 53% features of data. Although we should avoid loss of data but in case of raw datasets, these kinds of problems may arise. We cannot keep a data which is erroneous or may impart bias when training. In extreme worse cases of data, we should check our data sources also, to get a good quality of data.

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# From dates we can get mothly ,daily,yearly average counts of bikes which can help in data analysis
df_dates=pd.DataFrame()
df_dates['month']=df['timestamp'].dt.month_name()
df_dates['year']=df['timestamp'].dt.year
df_dates['day']=df['timestamp'].dt.day_name()
df_dates['stay_on_saturday']=df['stay_on_saturday']
df_dates
# Out:
#             month  year       day  stay_on_saturday
# 0        December  2012    Monday                 1
# 1        December  2012    Monday                 1
# 2        December  2012    Monday                 1
# 3        December  2012    Monday                 1
# 4        December  2012    Monday                 1
# ...           ...   ...       ...               ...
# 2380552     March  2013  Saturday                 0
# 2380553     March  2013  Saturday                 0
# 2380554     March  2013  Saturday                 0
# 2380555     March  2013  Saturday                 0
# 2380556     March  2013  Saturday                 0
#
# [2380557 rows x 4 columns]

# %%
df_dates['month'].value_counts()
# Out:
# June        358140
# March       339227
# May         328880
# April       311719
# January     295929
# February    281748
# November    236210
# December    228704
# Name: month, dtype: int64

# %%
# Checking the total number of distict year
df_dates['year'].drop_duplicates()
# Out:
# 0     2012
# 66    2013
# Name: year, dtype: int64

# %%
# making one more columns which till whether it is weekday or weekend
import numpy as np
df_dates['type_of_day']=np.where((df_dates['day']=='Saturday'),'weekend','weekday')

# %%
df_dates
# Out:
#             month  year       day  stay_on_saturday type_of_day
# 0        December  2012    Monday                 1     weekday
# 1        December  2012    Monday                 1     weekday
# 2        December  2012    Monday                 1     weekday
# 3        December  2012    Monday                 1     weekday
# 4        December  2012    Monday                 1     weekday
# ...           ...   ...       ...               ...         ...
# 2380552     March  2013  Saturday                 0     weekend
# 2380553     March  2013  Saturday                 0     weekend
# 2380554     March  2013  Saturday                 0     weekend
# 2380555     March  2013  Saturday                 0     weekend
# 2380556     March  2013  Saturday                 0     weekend
#
# [2380557 rows x 5 columns]

# %%
sns.barplot(x='type_of_day',y='stay_on_saturday',data=df_dates)
plt.show()

# %% [markdown]
# +1 if the stay includes a Saturday night, starts from Thursday with a length of stay is less than or equal to 4 nights (i.e. weekend); otherwise 0

# %%
# average counts during day of week 
plt.figure(figsize=(12,6))
sns.barplot(x='day',y='stay_on_saturday',data=df_dates)
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.countplot(x="month", hue='stay_on_saturday', data=df_dates, palette='cool')
plt.title("Booking according to month", fontsize=25)
plt.xlabel('Month')
plt.ylabel('Counting of Booking')
plt.show()

# %%
#Seprate the categorical columns and Numerical columns
cat_df,num_df=[],[]

for i in df:
    if df[i].dtype=='O':
        cat_df.append(i)
    elif (df[i].dtypes=='int64') | (df[i].dtypes=='float64') | (df[i].dtypes=='int32'):
        num_df.append(i)
    else: continue
        
print('>>> Total Number of Feature::', df.shape[1])
print('>>> Number of categorical features::', len(cat_df))
print('>>> Number of Numerical Feature::', len(num_df))
# Out:
# >>> Total Number of Feature:: 25
# >>> Number of categorical features:: 0
# >>> Number of Numerical Feature:: 24

# %%
#univariate analysis of numerical feature
for i in num_df:
    f=plt.figure(figsize=(17,3))
    f.add_subplot(1,2,1)
    sns.distplot(df[i].describe())
    f.add_subplot(1,2,2)
    sns.boxplot(df[i])

# %% [markdown]
# ## Exploring the Data Variables

# %%
#lets check each varibele number of unique value only
print('>>>Number of unique value in df<<<')
for i in df:
    print(i,'--->',df[i].nunique())
# Out:
# >>>Number of unique value in df<<<
# search_id ---> 95842
# timestamp ---> 95578
# site_id ---> 34
# user_country_id ---> 192
# listing_country_id ---> 166
# listing_id ---> 117378
# listing_stars ---> 6
# listing_review_score ---> 10
# is_brand ---> 2
# location_score1 ---> 337
# location_score2 ---> 9082
# log_historical_price ---> 381
# listing_position ---> 40
# price_usd ---> 62712
# has_promotion ---> 2
# destination_id ---> 13122
# length_of_stay ---> 33
# booking_window ---> 392
# num_adults ---> 9
# num_kids ---> 10
# num_rooms ---> 8
# stay_on_saturday ---> 2
# random_sort ---> 2
# clicked ---> 2
# booked ---> 2

# %% [markdown]
# ## Data Cleaning - listing_stars

# %%
df['listing_stars'].unique()
# Out:
# array([4, 5, 3, 0, 2, 1], dtype=int64)

# %%
print(df['listing_stars'].value_counts())
# Out:
# 3    934610
# 4    729978
# 2    429973
# 5    195919
# 0     81744
# 1      8333
# Name: listing_stars, dtype: int64

# %%
#Checking the number of listing stars .
sns.countplot(x='listing_stars', data=df, palette='magma')
plt.title('No of listing_stars',fontsize=18)
plt.show()

print(df['listing_stars'].value_counts())
# Out:
# 3    934610
# 4    729978
# 2    429973
# 5    195919
# 0     81744
# 1      8333
# Name: listing_stars, dtype: int64

# %% [markdown]
# The star rating of the hotel, from 1 to 5, in increments of 1.  A 0 indicates the property has no stars, the star rating is not known or cannot be publicized.

# %% [markdown]
# ### Data Cleaning - is_brand

# %%
df['is_brand'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
print(df['is_brand'].value_counts())
# Out:
# 1    1510911
# 0     869646
# Name: is_brand, dtype: int64

# %% [markdown]
# +1 if the hotel is part of a major hotel chain; 0 if it is an independent hotel

# %%
sns.countplot(x='is_brand', data=df, palette='magma')
plt.title('is_brand',fontsize=18)
plt.show()

print(df['is_brand'].value_counts())
# Out:
# 1    1510911
# 0     869646
# Name: is_brand, dtype: int64

# %% [markdown]
# ### Data Cleaning - has_promotion

# %%
df['has_promotion'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
print(df['has_promotion'].value_counts())
# Out:
# 0    1868919
# 1     511638
# Name: has_promotion, dtype: int64

# %% [markdown]
# +1 if the hotel had a sale price promotion specifically displayed

# %%
sns.countplot(x='has_promotion', data=df, palette='magma')
plt.title('has_promotion',fontsize=18)
plt.show()

print(df['has_promotion'].value_counts())
# Out:
# 0    1868919
# 1     511638
# Name: has_promotion, dtype: int64

# %% [markdown]
# ### Data Cleaning - num_adults

# %%
df['num_adults'].unique()
# Out:
# array([1, 2, 3, 4, 6, 5, 7, 8, 9], dtype=int64)

# %%
print(df['num_adults'].value_counts())
# Out:
# 2    1555653
# 1     560088
# 4     116247
# 3     113212
# 6      14369
# 5      12994
# 8       4949
# 7       2398
# 9        647
# Name: num_adults, dtype: int64

# %% [markdown]
# The number of adults specified in the hotel room

# %%
sns.countplot(x='num_adults', data=df, palette='magma')
plt.title('num_adults',fontsize=18)
plt.show()

print(df['num_adults'].value_counts())
# Out:
# 2    1555653
# 1     560088
# 4     116247
# 3     113212
# 6      14369
# 5      12994
# 8       4949
# 7       2398
# 9        647
# Name: num_adults, dtype: int64

# %% [markdown]
# ### Data Cleaning - num_kids

# %%
df['num_kids'].unique()
# Out:
# array([0, 2, 3, 1, 4, 6, 5, 7, 8, 9], dtype=int64)

# %%
print(df['num_kids'].value_counts())
# Out:
# 0    1829154
# 1     327609
# 2     184235
# 3      27919
# 4       8897
# 5       1356
# 6        934
# 7        284
# 8        155
# 9         14
# Name: num_kids, dtype: int64

# %% [markdown]
# The number of (extra occupancy) children specified in the hotel room

# %%
sns.countplot(x='num_kids', data=df, palette='magma')
plt.title('num_kids',fontsize=18)
plt.show()

print(df['num_kids'].value_counts())
# Out:
# 0    1829154
# 1     327609
# 2     184235
# 3      27919
# 4       8897
# 5       1356
# 6        934
# 7        284
# 8        155
# 9         14
# Name: num_kids, dtype: int64

# %% [markdown]
# ### Data Cleaning - num_rooms

# %%
df['num_rooms'].unique()
# Out:
# array([1, 2, 3, 4, 5, 8, 6, 7], dtype=int64)

# %%
print(df['num_rooms'].value_counts())
# Out:
# 1    2170850
# 2     177851
# 3      20916
# 4       6243
# 5       1955
# 6       1076
# 8       1010
# 7        656
# Name: num_rooms, dtype: int64

# %% [markdown]
# Number of hotel rooms specified in the search

# %%
sns.countplot(x='num_rooms', data=df, palette='magma')
plt.title('num_rooms',fontsize=18)
plt.show()

print(df['num_rooms'].value_counts())
# Out:
# 1    2170850
# 2     177851
# 3      20916
# 4       6243
# 5       1955
# 6       1076
# 8       1010
# 7        656
# Name: num_rooms, dtype: int64

# %% [markdown]
# ### Data Cleaning - stay_on_saturday

# %%
df['stay_on_saturday'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
print(df['stay_on_saturday'].value_counts())
# Out:
# 0    1194406
# 1    1186151
# Name: stay_on_saturday, dtype: int64

# %%
sns.countplot(x='booked', data=df, palette='magma')
plt.title('stay_on_saturday',fontsize=18)
plt.show()

print(df['stay_on_saturday'].value_counts())
# Out:
# 0    1194406
# 1    1186151
# Name: stay_on_saturday, dtype: int64

# %% [markdown]
# ### Data Cleaning - random_sort

# %%
df['random_sort'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
print(df['random_sort'].value_counts())
# Out:
# 0    1674158
# 1     706399
# Name: random_sort, dtype: int64

# %% [markdown]
# +1 when the displayed sort was random, 0 when the normal sort order was displayed

# %%
sns.countplot(x='random_sort', data=df, palette='magma')
plt.title('random_sort',fontsize=18)
plt.show()

print(df['random_sort'].value_counts())
# Out:
# 0    1674158
# 1     706399
# Name: random_sort, dtype: int64

# %% [markdown]
# ### Data Cleaning - clicked

# %%
df['clicked'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
print(df['clicked'].value_counts())
# Out:
# 0    2274463
# 1     106094
# Name: clicked, dtype: int64

# %% [markdown]
# if the listing is clicked 1, else 0

# %%
sns.countplot(x='clicked', data=df, palette='magma')
plt.title('clicked',fontsize=18)
plt.show()

print(df['clicked'].value_counts())
# Out:
# 0    2274463
# 1     106094
# Name: clicked, dtype: int64

# %% [markdown]
# ### Data Cleaning - booked

# %%
df['booked'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
print(df['booked'].value_counts())
# Out:
# 0    2314169
# 1      66388
# Name: booked, dtype: int64

# %% [markdown]
# if the listing is booked 1, else 0

# %%
sns.countplot(x='booked', data=df, palette='magma')
plt.title('booked',fontsize=18)
plt.show()

print(df['booked'].value_counts())
# Out:
# 0    2314169
# 1      66388
# Name: booked, dtype: int64

# %% [markdown]
# ## Question 2

# %% [markdown]
# ### a.	Calculate Click-Through Rates and Conversion Rates.

# %%
#click through rates(CTR)
# CTR= listing cliced/ listing id

CTR= (106094/117378)*100

# %%
CTR
# Out:
# 90.38661418664485

# %%
#Conversion rate (CR)
# CR= booking cliced/ listing id
CR= (66388/117378)*100

# %%
CR
# Out:
# 56.55915077782889

# %% [markdown]
# a.	This dataset has 3 possible outcome variables: clicked, booking_value and booked. Select one of those variables to model and train a machine learning model of your choice.

# %% [markdown]
# Booking value features is drop beacuse many value is Nan and out of two variable I have select for outcome variable is booked. Because booked is genrally gives the profit or sles.

# %%
df.head()
# Out:
#    search_id           timestamp  site_id  user_country_id  \
# 0          4 2012-12-31 08:59:22        5              219
# 1          4 2012-12-31 08:59:22        5              219
# 2          4 2012-12-31 08:59:22        5              219
# 3          4 2012-12-31 08:59:22        5              219
# 4          4 2012-12-31 08:59:22        5              219
#
#    listing_country_id  listing_id  listing_stars  listing_review_score  \
# 0                 219        3625              4                   4.0
# 1                 219       11622              4                   4.0
# 2                 219       11826              5                   4.5
# 3                 219       22824              3                   4.0
# 4                 219       37581              5                   4.5
#
#    is_brand  location_score1  ...  destination_id  length_of_stay  \
# 0         0             3.22  ...           12588               2
# 1         0             2.71  ...           12588               2
# 2         1             3.22  ...           12588               2
# 3         0             3.26  ...           12588               2
# 4         0             3.09  ...           12588               2
#
#    booking_window  num_adults  num_kids  num_rooms  stay_on_saturday  \
# 0              46           1         0          1                 1
# 1              46           1         0          1                 1
# 2              46           1         0          1                 1
# 3              46           1         0          1                 1
# 4              46           1         0          1                 1
#
#    random_sort  clicked  booked
# 0            1        0       0
# 1            1        0       0
# 2            1        0       0
# 3            1        0       0
# 4            1        0       0
#
# [5 rows x 25 columns]

# %%
df.drop(columns=['timestamp'],axis=1,inplace=True)

# %% [markdown]
# ## Removing Outliers

# %%
#Creating a copy of our dataset
df1=df.copy()

# %%
from scipy.stats import zscore
z=np.abs(zscore(df1))
z
# Out:
# array([[1.7346493 , 0.64819205, 0.66112502, ..., 1.53947692, 0.21597624,
#         0.1693742 ],
#        [1.7346493 , 0.64819205, 0.66112502, ..., 1.53947692, 0.21597624,
#         0.1693742 ],
#        [1.7346493 , 0.64819205, 0.66112502, ..., 1.53947692, 0.21597624,
#         0.1693742 ],
#        ...,
#        [1.72515596, 0.64819205, 0.66112502, ..., 1.53947692, 0.21597624,
#         0.1693742 ],
#        [1.72515596, 0.64819205, 0.66112502, ..., 1.53947692, 0.21597624,
#         0.1693742 ],
#        [1.72515596, 0.64819205, 0.66112502, ..., 1.53947692, 0.21597624,
#         0.1693742 ]])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([     10,      15,      31, ..., 2380534, 2380535, 2380546],
#       dtype=int64), array([ 5,  5, 22, ..., 15, 15, 22], dtype=int64))

# %%
df1_new=df1[(z<3).all(axis=1)]

# %%
#Checking the shape
print(df1.shape,'\t\t',df1_new.shape)
# Out:
# (2380557, 24) 		 (1893684, 24)

# %% [markdown]
# Observation: Maximum row detect as outliers but not remove the outliers beacuse dataset is inbalance and if we remove the outliers than some row detect which contain information about booked.

# %% [markdown]
# ## Model Training

# %%
#Splitting the data into x and y
x = df.drop(['booked'], axis=1)
y = df['booked']

# %%
#checking the shape of input and target variable
print(x.shape,'\t\t',y.shape)
# Out:
# (2380557, 23) 		 (2380557,)

# %%
#Scaling in input variables
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
x=ss.fit_transform(x)

# %%
#Splitting the data into training and testing data

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=42,stratify=y)

# %%
#Checking the shape

print(x_train.shape,'\t\t',x_test.shape)
# Out:
# (1904445, 23) 		 (476112, 23)

# %%
#Checking the shape

print(y_train.shape,'\t',y_test.shape)
# Out:
# (1904445,) 	 (476112,)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier

# %%
from sklearn.metrics import accuracy_score,roc_auc_score,confusion_matrix
from sklearn.model_selection import GridSearchCV,cross_val_score

# %%
LR=LogisticRegression()

# %%
models=[]
models.append(('LogisticRegression',LR))

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score,roc_curve,auc

# %%
Model=[]
score=[]
CVS=[]
rocscore=[]
for name,model in models:
    print('************',name,'**********')
    print('\n')
    Model.append(name)
    model.fit(x_train,y_train)
    print(model)
    pre=model.predict(x_test)
    print('\n')
    AS=accuracy_score(y_test,pre)
    print('Accuracy_score=',AS)
    score.append(AS*100)
    print('\n')
    sc=cross_val_score(model,x,y,cv=10,scoring='accuracy').mean()
    print('Cross_Val_Score=',sc)
    CVS.append(sc*100)
    print('\n')
    false_positive_rate,true_positive_rate,threshold=roc_curve(y_test,pre)
    roc_auc= auc(false_positive_rate,true_positive_rate)
    print('roc_auc_score=',roc_auc)
    rocscore.append(roc_auc*100)
    print('\n')
    print('classification_report\n',classification_report(y_test,pre))
    print('\n')
    cm=confusion_matrix(y_test,pre)
    print(cm)
    print('\n')
    plt.figure(figsize=(10,40))
    plt.subplot(911)
    plt.title(name)
    plt.plot(false_positive_rate,true_positive_rate,label='AUC = %0.2f'% roc_auc)
    plt.plot([0,1],[0,1],'r--')
    plt.legend(loc='lower right')
    plt.ylabel('True positive Rate')
    plt.xlabel('False Positive Rate')
    print('\n\n')
# Out:
# ************ LogisticRegression **********
#
#
# LogisticRegression()
#
#
# Accuracy_score= 0.9937997782034479
#
#
# Cross_Val_Score= 0.9938165730283647
#
#
# roc_auc_score= 0.9680622371899501
#
#
# classification_report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    462834
#            1       0.85      0.94      0.89     13278
#
#     accuracy                           0.99    476112
#    macro avg       0.93      0.97      0.95    476112
# weighted avg       0.99      0.99      0.99    476112
#
#
#
# [[460668   2166]
#  [   786  12492]]

# %%
result = pd.DataFrame({'Model':Model,'Accuracy_score': score,'cross_val_score':CVS,'Roc_auc_curve':rocscore})
result
# Out:
#                 Model  Accuracy_score  cross_val_score  Roc_auc_curve
# 0  LogisticRegression       99.379978        99.381657      96.806224

# %%
#save best model

import joblib
from joblib import dump #from joblib import load > to load .pkl file
joblib.dump(LR,'OTA.pkl')
# Out:
# ['OTA.pkl']
